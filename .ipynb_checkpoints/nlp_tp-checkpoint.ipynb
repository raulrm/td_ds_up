# %% [markdown]
# # Analisis de Sentimientos con las librerias TextBlob y TextaCy

# %%
# Cargamos las librerias necesarias
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import re
import string

# %%
# Funciones auxiliares
def limpiar_texto(text):
    '''
        Esta funcion recibe una estrada en str y remueve del mismo
        todos los caracteres que no son palabras
    '''
    text = text.lower()
    text = re.sub('\[.*?¿\]\%', ' ', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), ' ', text)
    text = re.sub('\w*\d\w*', '', text)
    text = re.sub('[‘’“”…«»]', '', text)
    text = re.sub('\n', ' ', text)
    return text

# %%
# Vamos a usar dos dataset que difieren en su formato
# Asi que los vamos a normalizar un poco

# Definimos el nombre de las columnas que tendra el dataset
col_nombre = ['Año','Mes', 'Dia','Titular']

# %%
# Cargamos los titulares de lanacion
# le ponemos nombre a las columnas y no lo dejamos elegir el titulo automatico
data_ln = pd.read_csv("tit_lanacion.csv", usecols=(0,1,2,4),names=col_nombre, header=None)
# Nos aseguramos que la columna Titular sea del tipo string
data_ln['Titular'] = data_ln['Titular'].astype(str)
data_ln.head()
# Out:
#     Año  Mes  Dia                              Titular
# 0  2006    9   10             bajo el signo del terror
# 1  2006    9   13  apple renovó toda la familia  ipod
# 2  2006    9   14                      por las canchas
# 3  2006    9   15                argentinos en francia
# 4  2006    9   15       ¿un loco suelto  en hollywood?

# %%
# Cargamos los titulares de perfil
# le ponemos nombre a las columnas y no lo dejamos elegir el titulo automatico
data_pe = pd.read_csv("tit_perfil.csv", usecols=(0,1,2,3),names=col_nombre, header=None)
# Nos aseguramos que la columna Titular sea del tipo string
data_pe['Titular'] = data_pe['Titular'].astype(str)
data_pe.head()
# Out:
#     Año  Mes  Dia                                            Titular
# 0  2006    9   10  córdoba: alianza delasotista se impone en marc...
# 1  2006    9   10             el reclutamiento docente cae en picada
# 2  2006    9   10  relatos de una obsesión: "ya no podía entrar a...
# 3  2006    9   10                el fuego en la mente de los hombres
# 4  2006    9   10                                   será injusticia

# %% [markdown]
# ## Probamos con TextBlob

# %%
# Cargamos las librerias necesarias
import textblob
from textblob import TextBlob

# %% [markdown]
# ### Extraemos el texto desde los dataset

# %%
# Cada columna de un pd es una "serie" que se puede extraer a una lista 
# y que se concatena en un string 
# En txt_ln queda el texto de todos los titulares
txt_ln_list = data_ln["Titular"].tolist()
txt_ln = ' '.join(txt_ln_list)

# Este texto tiene muchos caracteres que no son palabras
# Asi que los vamos a extraer con las funciones ya creadas
txt_ln_limpio = limpiar_texto(txt_ln)

#print(txt_ln)

# %%
txt_ln_serie = data_ln.query("Año == 2010")

# %%
# Cada columna de un pd es una "serie" que se puede extraer a una lista 
# y que se concatena en un string 
# En txt_pe queda el texto de todos los titulares
txt_pe_list = data_pe.query("Año == 2010")["Titular"].tolist()
txt_pe = ' '.join(txt_pe_list)

# Este texto tiene muchos caracteres que no son palabras
# Asi que los vamos a extraer con las funciones ya creadas
txt_pe_limpio = limpiar_texto(txt_pe)

print(txt_pe_limpio)
# Out:
# peajes bien chévere los placeres mínimos de cada día para estar saludables mateo ramos se postula para ser el primer bebé de  voraz incendio en berazategui el  último gran robo de   fue en un bingo más de  heridos por mal uso de pirotecnia mapa interactivo  cómo será el recorrido del dakar en capital fin de año en buenos aires a través de twitter  reviva la cobertura de perfil com exodo turístico  al menos  vehículos retenidos el papa pidió por la paz y el medio ambiente cristina recibió el  con su familia en el calafate scioli y rabolini rescataron a un hombre del río qué se puede llevar y traer en el auto al salir del país pakistán   muertos por un atentado  las vacaciones de luli fernández y pablo mouche  el verano politico de kirchner  duhalde y scioli más de  mil personas en las calles para seguir el dakar keynesianismo total en la argentina       repartiendo la herencia k  patrulla moral  y luego  la danza  los nuevos villeros  paisaje mal traducido  desde el ciber  ¿y si en vez de pelear armamos un equipo  detalles de urbanidad parecidos y diferencias presupuesto cosa e mandinga  preguntas sin respuestas  la gente reclama alternativas creíbles contra los kirchner periodistas  el gato de hemingway humor y jazz cómo  no  escribir un guión los municipios  en rojo  planean gastar más en  ee uu   otro incidente en un avión alerta por mayor circulación de billetes falsos un  que arranca con aumentos varios la madre de una de las víctimas del triple crimen embiste contra todos los políticos el perito que analizó los bienes de los k tenía antecedentes irregulares punta del este  un polista murió al ser atropellado arrancó el rally dakar en colón shakira presentó en sociedad su casa en punta del este por apurar los pagos de la deuda  boudou choca con el banco central dakar  un francés  líder provisional en motos un príncipe de qatar suelto en la argentina alberto f  criticó las presiones de cristina kirchner a los jueces cobos   duhalde irá por el pj y yo por la ucr  al final  marcos patronelli quedó como puntero en cuatris albinoni   menem es un seductor  un romántico nato  primera tragedia en el dakar  murió una mujer muerte en el dakar  las explicaciones de los organizadores robo de legajos de represores  detuvieron a un ex policía y scioli denunció una actitud  intimidatoria  dolido  el alemán que embistió a la mujer abandonó la competencia por qué la justicia podría inhabilitar a cristina para las elecciones de  aumenta la caída de pelo en las mujeres más jóvenes el anteúltimo año del poder k reciclándose campaña permanente zulma lobato y el calefón despelotes bicentenarios los desafíos de obama para    la paz tendrá que seguir esperando política  consenso  confianza los tres pepes orientales cobos  el mejor rival de kirchner en  macroeconomía del desarrollo las dos caras que conviven en las ciudades latinoamericanas la rebelión de la base de morón que  barrió con el último sostén de isabel remediogate  zanola sufre penurias en prisión y teme represalias estados unidos cerró su embajada en yemen lousteau y la menor de los ortega pasean en uruguay se largó la segunda etapa del dakar los estafadores del verano que buscan hacer su temporada incendios destruyen  colectivos y una fábrica  mientras el pj se reproduce  la ucr se acopla a cobos le pegó  tiros a su esposa y se suicidó murió otro argentino en uruguay scioli quiere evitar delitos de alto impacto en la costa casteu quedó segundo y saca más ventaja en motos los mejores chimentos políticos  y de sociedad  los patronelli se mantienen bien arriba el fmi ubicó a la argentina en el podio de las mayores inflaciones mundiales escribe lanata  cómo se vive hoy en rusia  el qatarí al attiyah es el nuevo líder del dakar la escuela secundaria inclina el balance   antibrindis carrió   oyarbide es un gran corrupto  intendentes ricos  conurbano pobre según came  las ventas minoristas  cayeron    hallan a un chico ahogado en el río de la plata hoyo en tiger  la esposa recibe us    ...

# %% [markdown]
# ### Hacemos el bag of words

# %% [markdown]
# ### Asignamos el sentiment a cada titular

# %% [markdown]
# ### Calculamos y Graficamos los sentimientos segun años

# %% [markdown]
# ## Probamos con TextaCy

# %%
# Importando las librerías que vamos a utilizar
import textacy
from textacy.datasets import Wikipedia
from collections import Counter, defaultdict
import warnings; warnings.simplefilter('ignore')

# graficos incrustados
# %matplotlib inline

# %% [markdown]
# ### Extraemos el texto desde los dataset

# %% [markdown]
# ### Hacemos el bag of words

# %% [markdown]
# ### Asignamos el sentiment a cada titular

# %% [markdown]
# ### Calculamos y Graficamos los sentimientos segun años
